# %% [markdown]
# # Download all the datasets for S5 experiments
# This notebook downloads all the raw datasets for the S5 experiments.  Individual notebooks are then run to convert them to the required format for the S5 code.
#
# Downloads:
# - LRA object.
#     - ListOps
#     - Pathfinder32
#     - PathX
#     - AAN (splits)
# - Retrieval (AAN, raw data)
# - Text (IMDB, from huggingface via Tensorflow Datasets)
# - Image (CIFAR, via Tensorflow Datasets)
# - Speech Commands

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# /var/folders/gd/kzc43rfd4rbd4ph3y89r0d1w0000gn/T/ipykernel_37874/912229180.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>

# %%
import os
import tensorflow_datasets as tfds

# %%
# Make a directory to dump the raw data into.
# !mkdir ./raw_datasets

# %%
# Clone and unpack the LRA object.
# This can take a long time, so get comfortable.
# !rm -rf ./raw_datasets/lra_release.gz ./raw_datasets/lra_release  # Clean out any old datasets.
# !wget -v https://storage.googleapis.com/long-range-arena/lra_release.gz -P ./raw_datasets
# !tar -zxf ./raw_datasets/lra_release.gz -C ./raw_datasets/

# %%
# Download the raw AAN data from the TutorialBank Corpus.
# !wget -v https://github.com/Yale-LILY/TutorialBank/blob/master/resources-v2022-clean.tsv -P ./raw_datasets
# Out:
# --2022-07-10 12:55:13--  https://github.com/Yale-LILY/TutorialBank/blob/master/resources-v2022-clean.tsv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./raw_datasets/resources-v2022-clean.tsv’
#
# resources-v2022-cle     [ <=>                ] 129.21K  --.-KB/s    in 0.09s
#
# 2022-07-10 12:55:14 (1.47 MB/s) - ‘./raw_datasets/resources-v2022-clean.tsv’ saved [132308]

# %%
# Download IMDB from hugging face.
import datasets
datasets.load_dataset('imdb');


# # We should be able to change the cache dir but i can't get it to work...
# cfg = datasets.DownloadConfig(cache_dir='./raw_datasets')
# datasets.load_dataset('imdb', data_dir='./raw_datasets', cache_dir='./raw_datasets', download_config=cfg)

# # Tensorflow Datasets can download and cache this directly.
# # We will then convert it to the right format later.
# cfg = tfds.download.DownloadConfig(extract_dir=os.getcwd() + '/raw_datasets/')
# ds = tfds.load('imdb_reviews', data_dir='./raw_datasets', download=True, download_and_prepare_kwargs={'download_dir': os.getcwd() + '/raw_datasets/', 'download_config': cfg})
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/Users/andrew/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })

# %%
# Download the Image (Cifar10) dataset via Tensorflow datasets.
cfg = tfds.download.DownloadConfig(extract_dir=os.getcwd() + '/raw_datasets/')
ds = tfds.load('cifar10', data_dir='./raw_datasets', download=True, download_and_prepare_kwargs={'download_dir': os.getcwd() + '/raw_datasets/', 'download_config': cfg})
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling raw_datasets/cifar10/3.0.2.incompleteNYX7BH/cifar10-train.tfrecord*...:   0%|          | 0/50000 [00…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling raw_datasets/cifar10/3.0.2.incompleteNYX7BH/cifar10-test.tfrecord*...:   0%|          | 0/10000 [00:…
# Dataset cifar10 downloaded and prepared to ./raw_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %%
# Download the Speech Commands dataset via Tensorflow datasets.
# !pip install pydub
cfg = tfds.download.DownloadConfig(extract_dir=os.getcwd() + '/raw_datasets/')
ds = tfds.load('speech_commands', data_dir='./raw_datasets', download=True, download_and_prepare_kwargs={'download_dir': os.getcwd() + '/raw_datasets/', 'download_config': cfg})
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# ...
# Generating train examples...:   0%|          | 0/85511 [00:00<?, ? examples/s]
# Shuffling raw_datasets/speech_commands/0.0.2.incompleteBHYKAC/speech_commands-train.tfrecord*...:   0%|       …
# Generating validation examples...:   0%|          | 0/10102 [00:00<?, ? examples/s]
# Shuffling raw_datasets/speech_commands/0.0.2.incompleteBHYKAC/speech_commands-validation.tfrecord*...:   0%|  …
# Generating test examples...:   0%|          | 0/4890 [00:00<?, ? examples/s]
# Shuffling raw_datasets/speech_commands/0.0.2.incompleteBHYKAC/speech_commands-test.tfrecord*...:   0%|        …
# Dataset speech_commands downloaded and prepared to ./raw_datasets/speech_commands/0.0.2. Subsequent calls will reuse this data.
